# %% [markdown]
# ## Introduction to Python
#
# Basic operations using pandas and numpy for data analysis and manipulation.
# You will learn:
# - load data
# - general data description
# - visualize data
# - Group, filter, merge and concatenate data
# - Define functions

# %% [markdown]
# ### Data description

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read csv file into a pandas dataframe
data = pd.read_csv("students-performance.csv")

# %%
# Take a look at the first few rows
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...  \
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2 class
# 0      4        3      4     1     1      3        4   0  11  High
# 1      5        3      3     1     1      3        2   9  11  High
# 2      4        3      2     2     3      3        6  12  13  High
# 3      3        2      2     1     1      5        0  14  14  High
# 4      4        3      2     1     2      5        0  11  13  High
#
# [5 rows x 33 columns]

# %%
# Get details of the data type for each attribute
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
# Total missing values for each attribute
# data.isnull().sum()

# %%
# Check if there is any missing value
data.isnull().values.any()
# Out:
# False

# %%
# Statistical details for each numerical attribute
data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000  \
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000  \
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
# Statistical details for each categorical attribute
data.describe(include = 'object')
# Out:
#        school  sex address famsize Pstatus   Mjob   Fjob  reason guardian
# count     649  649     649     649     649    649    649     649      649  \
# unique      2    2       2       2       2      5      5       4        3
# top        GP    F       U     GT3       T  other  other  course   mother
# freq      423  383     452     457     569    258    367     285      455
#
#        schoolsup famsup paid activities nursery higher internet romantic class
# count        649    649  649        649     649    649      649      649   649
# unique         2      2    2          2       2      2        2        2     2
# top           no    yes   no         no     yes    yes      yes       no  High
# freq         581    398  610        334     521    580      498      410   549

# %% [markdown]
# ### Data visualization

# %%
# Boxplot of Age
fig = plt.figure(figsize=(6, 2))
sns.set_theme(style="whitegrid")
sns.set(font_scale=0.9)
ax = sns.boxplot(x=data["age"])
ax.set_xlabel('Age')
plt.show()

# %%
# Boxplot of age by gender and school
fig = plt.figure(figsize=(4, 5))
sns.set_theme(style="whitegrid")
sns.set(font_scale=0.9)
ax = sns.boxplot(x=data["sex"], y=data["age"], hue=data['school'])
ax.set_xlabel('Gender')
ax.set_ylabel('Age')
plt.show()

# %%
# Histplot of age
fig = plt.figure(figsize=(5, 4))
ax = sns.histplot(data, x="age", bins=8)
ax.set_xlabel('Age')
ax.set_title('Age distribution')
plt.show()

# %%
# Histplot of mother's job
fig = plt.figure(figsize=(4, 4))
ax = sns.histplot(data, x="Mjob")
ax.set_xlabel("Mother's job")
plt.xticks(rotation=45)
plt.show()

# %%
# Correlation map for dimensionalty reduction
# Select numerical attributes
num_attr = data.select_dtypes(include=[np.number]).columns
corr_matrix = data[num_attr].corr()
sns.heatmap(corr_matrix, cmap="Blues")
plt.show()

# %%
# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Find attributes with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

to_drop

# Drop high correlated attributes 
# data.drop(to_drop, axis=1, inplace=True)
# Out:
# []

# %% [markdown]
# ### Groupby, filter, merge and concat

# %%
# Get the maximum of first period's grades by grouping school, age and gender
grp_g1 = data.groupby(['school', 'age', 'sex'])['G1'].max().reset_index(name='G1_max')

# %%
grp_g1
# Out:
#    school  age sex  G1_max
# 0      GP   15   F      16
# 1      GP   15   M      18
# 2      GP   16   F      17
# 3      GP   16   M      17
# 4      GP   17   F      18
# 5      GP   17   M      17
# 6      GP   18   F      18
# 7      GP   18   M      18
# 8      GP   19   F      14
# 9      GP   19   M      11
# 10     GP   20   F      11
# 11     GP   20   M      14
# 12     GP   21   F       9
# 13     GP   21   M       9
# 14     GP   22   M       7
# 15     MS   15   F      14
# 16     MS   15   M      13
# 17     MS   16   F      17
# 18     MS   16   M      14
# 19     MS   17   F      18
# 20     MS   17   M      15
# 21     MS   18   F      19
# 22     MS   18   M      17
# 23     MS   19   F      12
# 24     MS   19   M      10
# 25     MS   20   F      11
# 26     MS   20   M       8

# %%
# Get the maximum of second period's grades by grouping school, age and gender
grp_g2 = data.groupby(['school', 'age', 'sex'])['G2'].max().reset_index(name='G2_max')

# %%
grp_g2
# Out:
#    school  age sex  G2_max
# 0      GP   15   F      15
# 1      GP   15   M      17
# 2      GP   16   F      17
# 3      GP   16   M      17
# 4      GP   17   F      19
# 5      GP   17   M      18
# 6      GP   18   F      18
# 7      GP   18   M      18
# 8      GP   19   F      13
# 9      GP   19   M      13
# 10     GP   20   F      15
# 11     GP   20   M      15
# 12     GP   21   F      12
# 13     GP   21   M      10
# 14     GP   22   M       8
# 15     MS   15   F      16
# 16     MS   15   M      14
# 17     MS   16   F      17
# 18     MS   16   M      13
# 19     MS   17   F      18
# 20     MS   17   M      15
# 21     MS   18   F      18
# 22     MS   18   M      18
# 23     MS   19   F      13
# 24     MS   19   M      11
# 25     MS   20   F       9
# 26     MS   20   M      11

# %%
# Filter the school -- find Mousinho da Silveira (MS) school
grp_g1_ms = grp_g1.loc[grp_g1['school'] == 'MS']

# %%
grp_g1_ms
# Out:
#    school  age sex  G1_max
# 15     MS   15   F      14
# 16     MS   15   M      13
# 17     MS   16   F      17
# 18     MS   16   M      14
# 19     MS   17   F      18
# 20     MS   17   M      15
# 21     MS   18   F      19
# 22     MS   18   M      17
# 23     MS   19   F      12
# 24     MS   19   M      10
# 25     MS   20   F      11
# 26     MS   20   M       8

# %%
grp_g2_ms = grp_g2.loc[grp_g2['school'] == 'MS']

# %%
# Combining data on common columns
best_grades = pd.merge(grp_g1_ms, grp_g2_ms)

# %%
best_grades
# Out:
#    school  age sex  G1_max  G2_max
# 0      MS   15   F      14      16
# 1      MS   15   M      13      14
# 2      MS   16   F      17      17
# 3      MS   16   M      14      13
# 4      MS   17   F      18      18
# 5      MS   17   M      15      15
# 6      MS   18   F      19      18
# 7      MS   18   M      17      18
# 8      MS   19   F      12      13
# 9      MS   19   M      10      11
# 10     MS   20   F      11       9
# 11     MS   20   M       8      11

# %%
# Combining dataframes across rows
ms_grades = pd.concat([grp_g1_ms, grp_g2_ms])
ms_grades
# Out:
#    school  age sex  G1_max  G2_max
# 15     MS   15   F    14.0     NaN
# 16     MS   15   M    13.0     NaN
# 17     MS   16   F    17.0     NaN
# 18     MS   16   M    14.0     NaN
# 19     MS   17   F    18.0     NaN
# 20     MS   17   M    15.0     NaN
# 21     MS   18   F    19.0     NaN
# 22     MS   18   M    17.0     NaN
# 23     MS   19   F    12.0     NaN
# 24     MS   19   M    10.0     NaN
# 25     MS   20   F    11.0     NaN
# 26     MS   20   M     8.0     NaN
# 15     MS   15   F     NaN    16.0
# 16     MS   15   M     NaN    14.0
# 17     MS   16   F     NaN    17.0
# 18     MS   16   M     NaN    13.0
# 19     MS   17   F     NaN    18.0
# 20     MS   17   M     NaN    15.0
# 21     MS   18   F     NaN    18.0
# 22     MS   18   M     NaN    18.0
# 23     MS   19   F     NaN    13.0
# 24     MS   19   M     NaN    11.0
# 25     MS   20   F     NaN     9.0
# 26     MS   20   M     NaN    11.0

# %% [markdown]
# ### Apply function

# %%
# Get the average of the maximum grades
best_grades['grades_avg'] = best_grades[['G1_max', 'G2_max']].apply(np.average, axis=1)
best_grades
# Out:
#    school  age sex  G1_max  G2_max  grades_avg
# 0      MS   15   F      14      16        15.0
# 1      MS   15   M      13      14        13.5
# 2      MS   16   F      17      17        17.0
# 3      MS   16   M      14      13        13.5
# 4      MS   17   F      18      18        18.0
# 5      MS   17   M      15      15        15.0
# 6      MS   18   F      19      18        18.5
# 7      MS   18   M      17      18        17.5
# 8      MS   19   F      12      13        12.5
# 9      MS   19   M      10      11        10.5
# 10     MS   20   F      11       9        10.0
# 11     MS   20   M       8      11         9.5

# %%
# Change float type to integer
best_grades['grades_avg'] = best_grades['grades_avg'].astype(int)
best_grades
# Out:
#    school  age sex  G1_max  G2_max  grades_avg
# 0      MS   15   F      14      16          15
# 1      MS   15   M      13      14          13
# 2      MS   16   F      17      17          17
# 3      MS   16   M      14      13          13
# 4      MS   17   F      18      18          18
# 5      MS   17   M      15      15          15
# 6      MS   18   F      19      18          18
# 7      MS   18   M      17      18          17
# 8      MS   19   F      12      13          12
# 9      MS   19   M      10      11          10
# 10     MS   20   F      11       9          10
# 11     MS   20   M       8      11           9

# %% [markdown]
# ### For loop

# %%
# Transform grades_avg into a binary format by iterating each row
result = []
for i in range(len(best_grades)):
    if best_grades['grades_avg'][i] >= 15:
        result.append('High')
    else:
        result.append('Low')
best_grades['grades_binary'] = result

# %%
best_grades
# Out:
#    school  age sex  G1_max  G2_max  grades_avg grades_binary
# 0      MS   15   F      14      16          15          High
# 1      MS   15   M      13      14          13           Low
# 2      MS   16   F      17      17          17          High
# 3      MS   16   M      14      13          13           Low
# 4      MS   17   F      18      18          18          High
# 5      MS   17   M      15      15          15          High
# 6      MS   18   F      19      18          18          High
# 7      MS   18   M      17      18          17          High
# 8      MS   19   F      12      13          12           Low
# 9      MS   19   M      10      11          10           Low
# 10     MS   20   F      11       9          10           Low
# 11     MS   20   M       8      11           9           Low

# %%
# OR
best_grades['grades_binary_'] = ['High' if grade >=15 else 'Low' for grade in best_grades['grades_avg']]
best_grades
# Out:
#    school  age sex  G1_max  G2_max  grades_avg grades_binary grades_binary_
# 0      MS   15   F      14      16          15          High           High
# 1      MS   15   M      13      14          13           Low            Low
# 2      MS   16   F      17      17          17          High           High
# 3      MS   16   M      14      13          13           Low            Low
# 4      MS   17   F      18      18          18          High           High
# 5      MS   17   M      15      15          15          High           High
# 6      MS   18   F      19      18          18          High           High
# 7      MS   18   M      17      18          17          High           High
# 8      MS   19   F      12      13          12           Low            Low
# 9      MS   19   M      10      11          10           Low            Low
# 10     MS   20   F      11       9          10           Low            Low
# ...

# %% [markdown]
# ### Functions

# %%
# Define a function that averages high grades by gender, returns a list of tuples
def avg_high_grades(df):
    high_grades = df.loc[df['grades_binary'] == 'High']
    high_grades_grp = high_grades.groupby('sex')['grades_avg'].mean()
    # print(high_grades_grp)
    return list(zip(high_grades_grp.index, high_grades_grp))

# %%
avg_high_grades(best_grades)
# Out:
# [('F', 17.0), ('M', 16.0)]

# %%
# Define a function that takes two values, returns 1 value
def concatenate(value_1, value_2):
    return str(value_1)+ "--" + str(value_2)

# %%
best_grades['concatenated'] = best_grades[['age','sex']].apply(
    lambda row: concatenate(row['age'], row['sex']) , axis=1)

# %%
best_grades
# Out:
#    school  age sex  G1_max  G2_max  grades_avg grades_binary grades_binary_
# 0      MS   15   F      14      16          15          High           High  \
# 1      MS   15   M      13      14          13           Low            Low
# 2      MS   16   F      17      17          17          High           High
# 3      MS   16   M      14      13          13           Low            Low
# 4      MS   17   F      18      18          18          High           High
# 5      MS   17   M      15      15          15          High           High
# 6      MS   18   F      19      18          18          High           High
# 7      MS   18   M      17      18          17          High           High
# 8      MS   19   F      12      13          12           Low            Low
# 9      MS   19   M      10      11          10           Low            Low
# 10     MS   20   F      11       9          10           Low            Low
# ...

# %%
# Save dataframe into a csv file
best_grades.to_csv('output/intropython.csv', index=False)
